# %%
#!/usr/bin/env python3
import os
import sys
from collections import defaultdict
from pathlib import Path

# %%
#!/usr/bin/env python3
import os
import sys
from collections import defaultdict
from pathlib import Path

# Configuration
SAME_NAME = True
SAME_SIZE = True
INPUT_PATH = r"D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv"

# %%
#!/usr/bin/env python3
import os
import sys
from collections import defaultdict
from pathlib import Path

# Configuration
SAME_NAME = True
SAME_SIZE = True
INPUT_PATH = r"D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv"

def find_duplicates(path, check_name=True, check_size=True):
    """
    Find duplicate files based on name and optionally size.
    
    Args:
        path (str): Directory path to search
        check_name (bool): Whether to match by filename
        check_size (bool): Whether to match by file size
    
    Returns:
        dict: Dictionary with duplicate groups
    """
    if not path or not os.path.exists(path):
        print(f"Error: Path '{path}' does not exist or is empty")
        return {}
    
    # Dictionary to group files by their matching criteria
    file_groups = defaultdict(list)
    
    # Walk through all files in the directory tree
    for root, dirs, files in os.walk(path):
        for file in files:
            file_path = os.path.join(root, file)
            
            try:
                # Get file stats
                stat = os.stat(file_path)
                file_size = stat.st_size
                
                # Create key based on matching criteria
                if check_name and check_size:
                    key = (file, file_size)
                elif check_name:
                    key = file
                else:
                    key = file_size
                
                file_groups[key].append(file_path)
                
            except (OSError, IOError) as e:
                print(f"Warning: Could not access {file_path}: {e}")
                continue
    
    # Filter groups to only include duplicates (more than 1 file)
    duplicates = {k: v for k, v in file_groups.items() if len(v) > 1}
    
    return duplicates

def format_size(size_bytes):
    """Convert bytes to human readable format"""
    for unit in ['B', 'KB', 'MB', 'GB']:
        if size_bytes < 1024.0:
            return f"{size_bytes:.1f} {unit}"
        size_bytes /= 1024.0
    return f"{size_bytes:.1f} TB"

def print_duplicates(duplicates, check_name=True, check_size=True):
    """Print duplicate files in a formatted way"""
    if not duplicates:
        print("No duplicates found.")
        return
    
    print(f"\nFound {len(duplicates)} duplicate groups:")
    print("=" * 50)
    
    for i, (key, files) in enumerate(duplicates.items(), 1):
        if check_name and check_size:
            filename, size = key
            print(f"\nGroup {i}: '{filename}' ({format_size(size)})")
        elif check_name:
            print(f"\nGroup {i}: '{key}'")
        else:
            print(f"\nGroup {i}: Size {format_size(key)}")
        
        print(f"Found {len(files)} duplicates:")
        for file_path in sorted(files):
            print(f"  {file_path}")

def remove_duplicates(duplicates, keep_strategy='first', dry_run=True):
    """
    Remove duplicate files, keeping one based on strategy.
    
    Args:
        duplicates (dict): Dictionary of duplicate groups from find_duplicates()
        keep_strategy (str): 'first', 'last', 'shortest_path', 'longest_path'
        dry_run (bool): If True, only show what would be deleted without actually deleting
    
    Returns:
        tuple: (files_to_delete, files_kept, total_space_saved)
    """
    files_to_delete = []
    files_kept = []
    total_space_saved = 0
    
    for key, file_list in duplicates.items():
        if len(file_list) <= 1:
            continue
        
        # Sort files based on strategy
        if keep_strategy == 'first':
            sorted_files = sorted(file_list)
        elif keep_strategy == 'last':
            sorted_files = sorted(file_list, reverse=True)
        elif keep_strategy == 'shortest_path':
            sorted_files = sorted(file_list, key=len)
        elif keep_strategy == 'longest_path':
            sorted_files = sorted(file_list, key=len, reverse=True)
        else:
            sorted_files = file_list
        
        # Keep the first file based on strategy, delete the rest
        keep_file = sorted_files[0]
        delete_files = sorted_files[1:]
        
        files_kept.append(keep_file)
        
        for file_path in delete_files:
            try:
                file_size = os.path.getsize(file_path)
                total_space_saved += file_size
                files_to_delete.append((file_path, file_size))
                
                if not dry_run:
                    os.remove(file_path)
                    print(f"Deleted: {file_path}")
                    
            except (OSError, IOError) as e:
                print(f"Error deleting {file_path}: {e}")
    
    return files_to_delete, files_kept, total_space_saved

def preview_removal(duplicates, keep_strategy='first'):
    """Preview what files would be deleted without actually deleting them"""
    print(f"\n=== REMOVAL PREVIEW (Strategy: {keep_strategy}) ===")
    
    files_to_delete, files_kept, total_space_saved = remove_duplicates(
        duplicates, keep_strategy, dry_run=True
    )
    
    if not files_to_delete:
        print("No files to delete.")
        return files_to_delete, files_kept, total_space_saved
    
    print(f"\nFiles that would be KEPT ({len(files_kept)}):")
    for file_path in sorted(files_kept):
        print(f"  ✓ {file_path}")
    
    print(f"\nFiles that would be DELETED ({len(files_to_delete)}):")
    for file_path, size in sorted(files_to_delete):
        print(f"  ✗ {file_path} ({format_size(size)})")
    
    print(f"\nTotal space that would be saved: {format_size(total_space_saved)}")
    
    return files_to_delete, files_kept, total_space_saved

def confirm_and_delete(duplicates, keep_strategy='first'):
    """Show preview and ask for confirmation before deleting"""
    files_to_delete, files_kept, total_space_saved = preview_removal(duplicates, keep_strategy)
    
    if not files_to_delete:
        return
    
    print("\n" + "="*50)
    response = input(f"Delete {len(files_to_delete)} duplicate files? (yes/no): ").strip().lower()
    
    if response in ['yes', 'y']:
        print("\nDeleting files...")
        remove_duplicates(duplicates, keep_strategy, dry_run=False)
        print(f"\n✓ Deleted {len(files_to_delete)} duplicate files")
        print(f"✓ Saved {format_size(total_space_saved)} of disk space")
    else:
        print("Deletion cancelled.")

def main():
    # Use global configuration or get from command line
    global INPUT_PATH, SAME_NAME, SAME_SIZE
    
    # Only use command line arguments if not running in Jupyter
    # (Jupyter adds kernel arguments to sys.argv)
    if len(sys.argv) > 1 and not any('kernel' in arg for arg in sys.argv):
        INPUT_PATH = sys.argv[1]
        
        if len(sys.argv) > 2:
            SAME_NAME = sys.argv[2].lower() == 'true'
        
        if len(sys.argv) > 3:
            SAME_SIZE = sys.argv[3].lower() == 'true'
    
    # Validate input
    if not INPUT_PATH:
        INPUT_PATH = input("Enter the path to search for duplicates: ").strip()
    
    if not INPUT_PATH:
        print("Error: No input path provided")
        return
    
    # Expand user path if needed
    INPUT_PATH = os.path.expanduser(INPUT_PATH)
    
    print(f"Searching for duplicates in: {INPUT_PATH}")
    print(f"Match by name: {SAME_NAME}")
    print(f"Match by size: {SAME_SIZE}")
    
    # If size is false, only name will be matched
    if not SAME_SIZE:
        SAME_NAME = True
    
    # Find duplicates
    duplicates = find_duplicates(INPUT_PATH, SAME_NAME, SAME_SIZE)
    
    # Print results
    print_duplicates(duplicates, SAME_NAME, SAME_SIZE)
    
    # Summary
    total_duplicate_files = sum(len(files) for files in duplicates.values())
    print(f"\nSummary: {total_duplicate_files} duplicate files in {len(duplicates)} groups")
    
    return duplicates

if __name__ == "__main__":
    main()
# Out:
# Searching for duplicates in: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv
# Match by name: True
# Match by size: True
#
# Found 39 duplicate groups:
# ==================================================
#
# Group 1: 'accounting_accounts.csv' (8.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_accounts.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\accounting_accounts.csv
#
# Group 2: 'accounting_account_types.csv' (11.0 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_account_types.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\accounting_account_types.csv
#
# Group 3: 'account_detail_types.csv' (33.9 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_detail_types.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\account_detail_types.csv
#
# Group 4: 'account_subtypes.csv' (1.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_subtypes.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\account_subtypes.csv
#
# Group 5: 'barcodes.csv' (1.3 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\barcodes.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\barcodes.csv
#
# Group 6: 'brands.csv' (724.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\brands.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\brands.csv
#
# Group 7: 'business.csv' (6.9 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\business.csv
#
# Group 8: 'business_locations.csv' (1.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business_locations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\business_locations.csv
#
# Group 9: 'categories.csv' (417.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\categories.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\categories.csv
#
# Group 10: 'contacts.csv' (15.3 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\contacts.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\contacts.csv
#
# Group 11: 'countries.csv' (5.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\countries.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\countries.csv
#
# Group 12: 'currencies.csv' (5.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\currencies.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\currencies.csv
#
# Group 13: 'cutomer_invoices.csv' (172.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\cutomer_invoices.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\cutomer_invoices.csv
#
# Group 14: 'invoice_layouts.csv' (1.5 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_layouts.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_layouts.csv
#
# Group 15: 'invoice_products.csv' (973.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_products.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_products.csv
#
# Group 16: 'invoice_schemes.csv' (204.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_schemes.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_schemes.csv
#
# Group 17: 'media.csv' (394.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\media.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\media.csv
#
# Group 18: 'migrations.csv' (28.0 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\migrations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\migrations.csv
#
# Group 19: 'model_has_permissions.csv' (65.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_permissions.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\model_has_permissions.csv
#
# Group 20: 'model_has_roles.csv' (71.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_roles.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\model_has_roles.csv
#
# Group 21: 'notification_templates.csv' (4.8 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\notification_templates.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\notification_templates.csv
#
# Group 22: 'payment_types.csv' (345.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\payment_types.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\payment_types.csv
#
# Group 23: 'permissions.csv' (5.9 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\permissions.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\permissions.csv
#
# Group 24: 'products.csv' (4.9 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\products.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\products.csv
#
# Group 25: 'product_locations.csv' (490.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_locations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_locations.csv
#
# Group 26: 'product_racks.csv' (1.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_racks.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_racks.csv
#
# Group 27: 'product_variations.csv' (1.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_variations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_variations.csv
#
# Group 28: 'purchase_lines.csv' (3.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\purchase_lines.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\purchase_lines.csv
#
# Group 29: 'put_away_products.csv' (1.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\put_away_products.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\put_away_products.csv
#
# Group 30: 'reference_counts.csv' (412.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\reference_counts.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\reference_counts.csv
#
# Group 31: 'roles.csv' (280.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\roles.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\roles.csv
#
# Group 32: 'role_has_permissions.csv' (130.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\role_has_permissions.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\role_has_permissions.csv
#
# Group 33: 'system.csv' (253.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\system.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\system.csv
#
# Group 34: 'tax_rates.csv' (187.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\tax_rates.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\tax_rates.csv
#
# Group 35: 'units.csv' (255.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\units.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\units.csv
#
# Group 36: 'users.csv' (1.7 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\users.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\users.csv
#
# Group 37: 'variations.csv' (2.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\variations.csv
#
# Group 38: 'variation_location_details.csv' (1.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variation_location_details.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\variation_location_details.csv
#
# Group 39: 'vendor_invoices.csv' (308.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\vendor_invoices.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\vendor_invoices.csv
#
# Summary: 78 duplicate files in 39 groups

# %% [markdown]
# # Deletion

# %%
# Step 1: Find duplicates (you already did this)
duplicates = main()

# Step 2: Preview what would be deleted
preview_removal(duplicates, 'shortest_path')

# Step 3: Delete with confirmation
confirm_and_delete(duplicates, 'shortest_path')
# Out:
# Searching for duplicates in: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv
# Match by name: True
# Match by size: True
#
# Found 39 duplicate groups:
# ==================================================
#
# Group 1: 'accounting_accounts.csv' (8.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_accounts.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\accounting_accounts.csv
#
# Group 2: 'accounting_account_types.csv' (11.0 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_account_types.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\accounting_account_types.csv
#
# Group 3: 'account_detail_types.csv' (33.9 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_detail_types.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\account_detail_types.csv
#
# Group 4: 'account_subtypes.csv' (1.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_subtypes.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\account_subtypes.csv
#
# Group 5: 'barcodes.csv' (1.3 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\barcodes.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\barcodes.csv
#
# Group 6: 'brands.csv' (724.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\brands.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\brands.csv
#
# Group 7: 'business.csv' (6.9 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\business.csv
#
# Group 8: 'business_locations.csv' (1.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business_locations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\business_locations.csv
#
# Group 9: 'categories.csv' (417.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\categories.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\categories.csv
#
# Group 10: 'contacts.csv' (15.3 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\contacts.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\contacts.csv
#
# Group 11: 'countries.csv' (5.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\countries.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\countries.csv
#
# Group 12: 'currencies.csv' (5.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\currencies.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\currencies.csv
#
# Group 13: 'cutomer_invoices.csv' (172.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\cutomer_invoices.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\cutomer_invoices.csv
#
# Group 14: 'invoice_layouts.csv' (1.5 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_layouts.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_layouts.csv
#
# Group 15: 'invoice_products.csv' (973.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_products.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_products.csv
#
# Group 16: 'invoice_schemes.csv' (204.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_schemes.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_schemes.csv
#
# Group 17: 'media.csv' (394.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\media.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\media.csv
#
# Group 18: 'migrations.csv' (28.0 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\migrations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\migrations.csv
#
# Group 19: 'model_has_permissions.csv' (65.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_permissions.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\model_has_permissions.csv
#
# Group 20: 'model_has_roles.csv' (71.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_roles.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\model_has_roles.csv
#
# Group 21: 'notification_templates.csv' (4.8 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\notification_templates.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\notification_templates.csv
#
# Group 22: 'payment_types.csv' (345.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\payment_types.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\payment_types.csv
#
# Group 23: 'permissions.csv' (5.9 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\permissions.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\permissions.csv
#
# Group 24: 'products.csv' (4.9 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\products.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\products.csv
#
# Group 25: 'product_locations.csv' (490.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_locations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_locations.csv
#
# Group 26: 'product_racks.csv' (1.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_racks.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_racks.csv
#
# Group 27: 'product_variations.csv' (1.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_variations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_variations.csv
#
# Group 28: 'purchase_lines.csv' (3.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\purchase_lines.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\purchase_lines.csv
#
# Group 29: 'put_away_products.csv' (1.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\put_away_products.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\put_away_products.csv
#
# Group 30: 'reference_counts.csv' (412.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\reference_counts.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\reference_counts.csv
#
# Group 31: 'roles.csv' (280.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\roles.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\roles.csv
#
# Group 32: 'role_has_permissions.csv' (130.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\role_has_permissions.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\role_has_permissions.csv
#
# Group 33: 'system.csv' (253.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\system.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\system.csv
#
# Group 34: 'tax_rates.csv' (187.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\tax_rates.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\tax_rates.csv
#
# Group 35: 'units.csv' (255.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\units.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\units.csv
#
# Group 36: 'users.csv' (1.7 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\users.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\users.csv
#
# Group 37: 'variations.csv' (2.2 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variations.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\variations.csv
#
# Group 38: 'variation_location_details.csv' (1.1 KB)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variation_location_details.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\variation_location_details.csv
#
# Group 39: 'vendor_invoices.csv' (308.0 B)
# Found 2 duplicates:
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\vendor_invoices.csv
#   D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\vendor_invoices.csv
#
# Summary: 78 duplicate files in 39 groups
#
# === REMOVAL PREVIEW (Strategy: shortest_path) ===
#
# Files that would be KEPT (39):
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\account_detail_types.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\account_subtypes.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\accounting_account_types.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\accounting_accounts.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\barcodes.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\brands.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\business.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\business_locations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\categories.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\contacts.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\countries.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\currencies.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\cutomer_invoices.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_layouts.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_products.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_schemes.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\media.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\migrations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\model_has_permissions.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\model_has_roles.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\notification_templates.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\payment_types.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\permissions.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_locations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_racks.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_variations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\products.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\purchase_lines.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\put_away_products.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\reference_counts.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\role_has_permissions.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\roles.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\system.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\tax_rates.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\units.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\users.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\variation_location_details.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\variations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\vendor_invoices.csv
#
# Files that would be DELETED (39):
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_detail_types.csv (33.9 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_subtypes.csv (1.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_account_types.csv (11.0 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_accounts.csv (8.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\barcodes.csv (1.3 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\brands.csv (724.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business.csv (6.9 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business_locations.csv (1.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\categories.csv (417.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\contacts.csv (15.3 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\countries.csv (5.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\currencies.csv (5.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\cutomer_invoices.csv (172.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_layouts.csv (1.5 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_products.csv (973.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_schemes.csv (204.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\media.csv (394.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\migrations.csv (28.0 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_permissions.csv (65.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_roles.csv (71.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\notification_templates.csv (4.8 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\payment_types.csv (345.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\permissions.csv (5.9 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_locations.csv (490.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_racks.csv (1.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_variations.csv (1.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\products.csv (4.9 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\purchase_lines.csv (3.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\put_away_products.csv (1.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\reference_counts.csv (412.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\role_has_permissions.csv (130.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\roles.csv (280.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\system.csv (253.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\tax_rates.csv (187.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\units.csv (255.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\users.csv (1.7 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variation_location_details.csv (1.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variations.csv (2.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\vendor_invoices.csv (308.0 B)
#
# Total space that would be saved: 151.6 KB
#
# === REMOVAL PREVIEW (Strategy: shortest_path) ===
#
# Files that would be KEPT (39):
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\account_detail_types.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\account_subtypes.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\accounting_account_types.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\accounting_accounts.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\barcodes.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\brands.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\business.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\business_locations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\categories.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\contacts.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\countries.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\currencies.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\cutomer_invoices.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_layouts.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_products.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\invoice_schemes.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\media.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\migrations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\model_has_permissions.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\model_has_roles.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\notification_templates.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\payment_types.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\permissions.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_locations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_racks.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\product_variations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\products.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\purchase_lines.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\put_away_products.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\reference_counts.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\role_has_permissions.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\roles.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\system.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\tax_rates.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\units.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\users.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\variation_location_details.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\variations.csv
#   ✓ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables\vendor_invoices.csv
#
# Files that would be DELETED (39):
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_detail_types.csv (33.9 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_subtypes.csv (1.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_account_types.csv (11.0 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_accounts.csv (8.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\barcodes.csv (1.3 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\brands.csv (724.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business.csv (6.9 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business_locations.csv (1.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\categories.csv (417.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\contacts.csv (15.3 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\countries.csv (5.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\currencies.csv (5.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\cutomer_invoices.csv (172.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_layouts.csv (1.5 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_products.csv (973.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_schemes.csv (204.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\media.csv (394.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\migrations.csv (28.0 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_permissions.csv (65.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_roles.csv (71.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\notification_templates.csv (4.8 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\payment_types.csv (345.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\permissions.csv (5.9 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_locations.csv (490.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_racks.csv (1.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_variations.csv (1.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\products.csv (4.9 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\purchase_lines.csv (3.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\put_away_products.csv (1.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\reference_counts.csv (412.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\role_has_permissions.csv (130.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\roles.csv (280.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\system.csv (253.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\tax_rates.csv (187.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\units.csv (255.0 B)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\users.csv (1.7 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variation_location_details.csv (1.1 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variations.csv (2.2 KB)
#   ✗ D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\vendor_invoices.csv (308.0 B)
#
# Total space that would be saved: 151.6 KB
#
# ==================================================
# Deleting files...
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_accounts.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\accounting_account_types.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_detail_types.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\account_subtypes.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\barcodes.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\brands.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\business_locations.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\categories.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\contacts.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\countries.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\currencies.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\cutomer_invoices.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_layouts.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_products.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\invoice_schemes.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\media.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\migrations.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_permissions.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\model_has_roles.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\notification_templates.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\payment_types.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\permissions.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\products.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_locations.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_racks.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\product_variations.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\purchase_lines.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\put_away_products.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\reference_counts.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\roles.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\role_has_permissions.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\system.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\tax_rates.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\units.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\users.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variations.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\variation_location_details.csv
# Deleted: D:\OneDrive - Green Energy\Sakib\Scripts\downloaded_db_tables_csv\all_tables-before\vendor_invoices.csv
#
# ✓ Deleted 39 duplicate files
# ✓ Saved 151.6 KB of disk space
